# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# Feature extraction
from sklearn.feature_selection import VarianceThreshold

from boruta import BorutaPy
from sklearn.inspection import permutation_importance

from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import squareform

# Classification models
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
data_path = "../../data/"

# %%
df_radiomics = pd.read_excel(data_path + 'quantitative_radiomic_features.xls')
df_radiomics['Lesion Name'] = df_radiomics['Lesion Name'].str.replace(r'-1\.les|-S2-1\.les', '', regex=True)

df_clinical = pd.read_excel(data_path + "clinical_data.xls")
df_clinical.replace("[Not Available]", np.nan, inplace=True)
df_clinical.rename(columns={'bcr_patient_barcode': 'Lesion Name'}, inplace=True)
df_clinical = df_clinical[['Lesion Name', 'age_at_initial_pathologic_diagnosis', 'ajcc_neoplasm_disease_stage', "ajcc_tumor_stage_code", "number_of_lymphnodes_positive_by_he",
                          "breast_carcinoma_estrogen_receptor_status", "breast_carcinoma_progesterone_receptor_status"]]

target_class = pd.read_csv(data_path + 'target_class.csv')
target_class.rename(columns={'CLID': 'Lesion Name'}, inplace=True)
# Out:
# /tmp/ipykernel_2791/3106461490.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_clinical.replace("[Not Available]", np.nan, inplace=True)

# %%
df = pd.merge(df_radiomics, target_class, on='Lesion Name', how='inner')
df = pd.merge(df, df_clinical, on='Lesion Name', how='inner')
df = df.drop(columns=df.columns[0])
df
# Out:
#     Maximum enhancement (K1)  Time to peak (K2)  Uptake rate (K3)  \
# 0                   1.602573            145.433          0.011019
# 1                   4.072152            144.752          0.028132
# 2                   1.303264            168.383          0.007740
# 3                   0.758630             60.000          0.012644
# 4                   3.353556             60.000          0.055893
# ..                       ...                ...               ...
# 71                  1.277688             60.000          0.021295
# 72                  1.495674             60.000          0.024928
# 73                  2.182750             60.000          0.036379
# 74                  1.354828            192.786          0.007028
# 75                  1.825341            201.786          0.009046
#
#     Washout rate (K4)  Curve shape index (K5)   E1 (K6)  \
# 0            0.000809               -0.099998  1.550204
# 1            0.001510               -0.007311  3.973258
# 2            0.000667               -0.146959  1.273733
# 3            0.000479               -0.150482  0.758630
# 4            0.000920               -0.080066  3.353556
# ..                ...                     ...       ...
# 71           0.000611               -0.149392  1.277688
# 72           0.000093               -0.017541  1.495674
# 73           0.001081               -0.125678  2.182750
# 74           0.000067                0.043301  1.290058
# 75           0.001355               -0.057510  1.732952
#
#     Signal Enhancement Ratio (SER) (K7)  Maximum enhancement-variance (E1)  \
# 0                              1.111109                           0.125963
# 1                              1.007365                           4.054312
# 2                              1.172277                           0.534411
# 3                              1.177138                           0.037956
# 4                              1.087034                           2.330160
# ..                                  ...                                ...
# 71                             1.175629                           0.271695
# 72                             1.017854                           0.123041
# 73                             1.143744                           0.225339
# 74                             0.958496                           0.108778
# 75                             1.061019                          10.346100
#
#     Enhancement-Variance Time to Peak (E2)  \
# 0                                   60.000
# 1                                  229.504
# 2                                   60.000
# 3                                  298.418
# 4                                   60.000
# ..                                     ...
# 71                                  60.000
# 72                                  60.000
# 73                                 313.733
# 74                                  60.000
# 75                                 343.572
#
#     Enhancement-variance Increasing Rate (E3)  ...  \
# 0                                    0.002099  ...
# 1                                    0.017666  ...
# 2                                    0.008907  ...
# 3                                    0.000127  ...
# 4                                    0.038836  ...
# ..                                        ...  ...
# 71                                   0.004528  ...
# 72                                   0.002051  ...
# 73                                   0.000718  ...
# 74                                   0.001813  ...
# 75                                   0.030113  ...
#
#     Surface Area to Volume ratio (G3)  Volume of most enhancing voxels (S4)  \
# 0                            0.922937                              22.15705
# 1                            0.849641                             111.70860
# 2                            0.842762                             236.23630
# 3                            1.028034                             122.69640
# 4                            0.918724                             245.36130
# ..                                ...                                   ...
# 71                           0.978195                              94.23584
# 72                           1.142819                              88.69263
# 73                           0.679105                              89.18701
# 74                           0.986278                              36.73828
# 75                           1.145957                              20.66528
#
#     Maximum Diameter (S5)  Pam50.Call  age_at_initial_pathologic_diagnosis  \
# 0                27.60382        LumA                                   29
# 1                21.31066        LumA                                   41
# 2                41.33787        LumA                                   61
# 3                11.39449        LumA                                   56
# 4                68.62797        LumB                                   40
# ..                    ...         ...                                  ...
# 71               51.20215        LumA                                   66
# 72               22.50068        LumA                                   46
# 73               30.87951       Basal                                   44
# 74               23.13763        LumA                                   61
# 75               22.69077        LumA                                   45
#
#     ajcc_neoplasm_disease_stage  ajcc_tumor_stage_code  \
# 0                      Stage IA                    T1c
# 1                      Stage IA                    T1c
# 2                    Stage IIIC                     T2
# 3                     Stage IIA                    T1c
# 4                     Stage IIB                     T2
# ..                          ...                    ...
# 71                    Stage IIA                     T2
# 72                    Stage IIA                     T2
# 73                    Stage IIA                     T2
# 74                    Stage IIB                     T2
# 75                    Stage IIB                     T2
#
#     number_of_lymphnodes_positive_by_he  \
# 0                                   0.0
# 1                                   0.0
# 2                                  15.0
# 3                                   0.0
# 4                                   2.0
# ..                                  ...
# 71                                  0.0
# 72                                  0.0
# 73                                  0.0
# 74                                  1.0
# 75                                  1.0
#
#     breast_carcinoma_estrogen_receptor_status  \
# 0                                    Positive
# 1                                    Positive
# 2                                    Positive
# 3                                    Positive
# 4                                    Positive
# ..                                        ...
# 71                                   Positive
# 72                                   Positive
# 73                                   Negative
# 74                                   Positive
# 75                                   Positive
#
#     breast_carcinoma_progesterone_receptor_status
# 0                                        Positive
# 1                                        Positive
# 2                                        Positive
# 3                                        Negative
# 4                                        Positive
# ..                                            ...
# 71                                       Positive
# 72                                       Positive
# 73                                       Negative
# 74                                       Positive
# 75                                       Positive
#
# [76 rows x 43 columns]

# %%
from sklearn.preprocessing import StandardScaler

radiomic_features = df.drop(columns=["Pam50.Call", 'age_at_initial_pathologic_diagnosis', 'ajcc_neoplasm_disease_stage', "ajcc_tumor_stage_code", "number_of_lymphnodes_positive_by_he",
                                    "breast_carcinoma_estrogen_receptor_status", "breast_carcinoma_progesterone_receptor_status"])

scaler = StandardScaler()
scaled_features = scaler.fit_transform(radiomic_features)

df_scaled = pd.DataFrame(scaled_features, columns=radiomic_features.columns)

df_scaled["Pam50.Call"] = df["Pam50.Call"].values
df_scaled["age_at_initial_pathologic_diagnosis"] = df["age_at_initial_pathologic_diagnosis"].values
df_scaled["ajcc_neoplasm_disease_stage"] = df["ajcc_neoplasm_disease_stage"].values
df_scaled["ajcc_tumor_stage_code"] = df["ajcc_tumor_stage_code"].values
df_scaled["number_of_lymphnodes_positive_by_he"] = df["number_of_lymphnodes_positive_by_he"].values 
df_scaled["breast_carcinoma_estrogen_receptor_status"] = df["breast_carcinoma_estrogen_receptor_status"].values
df_scaled["breast_carcinoma_progesterone_receptor_status"] = df["breast_carcinoma_progesterone_receptor_status"].values 

df = df_scaled
df_dummies = pd.get_dummies(df, columns=['ajcc_neoplasm_disease_stage', "ajcc_tumor_stage_code",
                                        "breast_carcinoma_estrogen_receptor_status", 
                                         "breast_carcinoma_progesterone_receptor_status"], drop_first=True)

new_dummy_columns = set(df_dummies.columns) - set(df.columns)

df = df_dummies

# %%
df
# Out:
#     Maximum enhancement (K1)  Time to peak (K2)  Uptake rate (K3)  \
# 0                  -0.195663           0.011278         -0.496149
# 1                   2.618630           0.003479          0.917726
# 2                  -0.536750           0.274115         -0.767103
# 3                  -1.157407          -0.967149         -0.361928
# 4                   1.799730          -0.967149          3.211365
# ..                       ...                ...               ...
# 71                 -0.565896          -0.967149          0.352830
# 72                 -0.317483          -0.967149          0.653004
# 73                  0.465498          -0.967149          1.599129
# 74                 -0.477989           0.553592         -0.825950
# 75                  0.058200           0.656665         -0.659195
#
#     Washout rate (K4)  Curve shape index (K5)   E1 (K6)  \
# 0           -0.151982               -0.297797 -0.155749
# 1            0.397861                0.255429  2.655287
# 2           -0.263946               -0.578093 -0.476489
# 3           -0.411282               -0.599120 -1.074071
# 4           -0.065331               -0.178825  1.936358
# ..                ...                     ...       ...
# 71          -0.307554               -0.592611 -0.471901
# 72          -0.714435                0.194371 -0.219010
# 73           0.061532               -0.451073  0.578081
# 74          -0.734472                0.557517 -0.457550
# 75           0.276111               -0.044192  0.056261
#
#     Signal Enhancement Ratio (SER) (K7)  Maximum enhancement-variance (E1)  \
# 0                              0.009570                          -0.130554
# 1                             -0.257523                          -0.074160
# 2                              0.167049                          -0.124690
# 3                              0.179564                          -0.131817
# 4                             -0.052412                          -0.098911
# ..                                  ...                                ...
# 71                             0.175679                          -0.128462
# 72                            -0.230518                          -0.130596
# 73                             0.093590                          -0.129127
# 74                            -0.383337                          -0.130801
# 75                            -0.119389                           0.016163
#
#     Enhancement-Variance Time to Peak (E2)  \
# 0                                -1.065664
# 1                                 0.222799
# 2                                -1.065664
# 3                                 0.746640
# 4                                -1.065664
# ..                                     ...
# 71                               -1.065664
# 72                               -1.065664
# 73                                0.863055
# 74                               -1.065664
# 75                                1.089872
#
#     Enhancement-variance Increasing Rate (E3)  ...  \
# 0                                   -0.123696  ...
# 1                                   -0.093276  ...
# 2                                   -0.110393  ...
# 3                                   -0.127551  ...
# 4                                   -0.051902  ...
# ..                                        ...  ...
# 71                                  -0.118950  ...
# 72                                  -0.123792  ...
# 73                                  -0.126395  ...
# 74                                  -0.124256  ...
# 75                                  -0.068949  ...
#
#     ajcc_neoplasm_disease_stage_Stage IIA  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                    True
# 4                                   False
# ..                                    ...
# 71                                   True
# 72                                   True
# 73                                   True
# 74                                  False
# 75                                  False
#
#     ajcc_neoplasm_disease_stage_Stage IIB  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                    True
# ..                                    ...
# 71                                  False
# 72                                  False
# 73                                  False
# 74                                   True
# 75                                   True
#
#     ajcc_neoplasm_disease_stage_Stage IIIA  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 71                                   False
# 72                                   False
# 73                                   False
# 74                                   False
# 75                                   False
#
#     ajcc_neoplasm_disease_stage_Stage IIIC  ajcc_tumor_stage_code_T1b  \
# 0                                    False                      False
# 1                                    False                      False
# 2                                     True                      False
# 3                                    False                      False
# 4                                    False                      False
# ..                                     ...                        ...
# 71                                   False                      False
# 72                                   False                      False
# 73                                   False                      False
# 74                                   False                      False
# 75                                   False                      False
#
#     ajcc_tumor_stage_code_T1c  ajcc_tumor_stage_code_T2  \
# 0                        True                     False
# 1                        True                     False
# 2                       False                      True
# 3                        True                     False
# 4                       False                      True
# ..                        ...                       ...
# 71                      False                      True
# 72                      False                      True
# 73                      False                      True
# 74                      False                      True
# 75                      False                      True
#
#     ajcc_tumor_stage_code_T3  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 71                     False
# 72                     False
# 73                     False
# 74                     False
# 75                     False
#
#     breast_carcinoma_estrogen_receptor_status_Positive  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 71                                               True
# 72                                               True
# 73                                              False
# 74                                               True
# 75                                               True
#
#     breast_carcinoma_progesterone_receptor_status_Positive
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                               False
# 4                                                True
# ..                                                ...
# 71                                               True
# 72                                               True
# 73                                              False
# 74                                               True
# 75                                               True
#
# [76 rows x 51 columns]

# %%
features = df.columns.difference(['Pam50.Call'])
target_col = 'Pam50.Call'

X_train, X_test, y_train, y_test = train_test_split(
    df[features],
    df[target_col],
    test_size=0.2,
    random_state=42,
    stratify=df[target_col]
)

# %%
X_train
# Out:
#     Contrast (T1)  Correlation (T2)  Curve shape index (K5)  \
# 11      -0.684527          0.679692               -0.349218
# 70       1.180559         -1.166517               -0.231014
# 44       0.425652         -0.410766               -0.190543
# 36      -0.247246          0.327783               -0.586582
# 22      -1.962088          1.926856               -0.609998
# 16      -1.519470          1.495774                0.193791
# 12       0.365084         -0.408202               -0.692573
# 55      -1.416246          1.406506               -0.551006
# 9        1.948630         -1.850265               -0.388592
# 51      -1.266737          1.256714                0.680154
# 38       0.000722          0.028911                1.279733
# 41      -1.443959          1.456929               -4.224826
# 3       -0.165973          0.154708               -0.599120
# 18      -1.115510          1.134648                0.698946
# 59       1.311407         -1.343411               -0.039172
# 10       0.474278         -0.532981               -0.427666
# 67       0.461316         -0.449025               -1.246098
# 73       0.785688         -0.786756               -0.451073
# 29      -0.495916          0.510535               -0.088319
# 48       0.906580         -0.764116                1.141584
# 61       0.742025         -0.597933               -0.152540
# 74       1.272052         -1.446566                0.557517
# 47      -1.190521          1.174064                1.362383
# 20       0.230359         -0.270400               -0.084558
# 60       0.023557         -0.003692                0.948896
# 72       1.514138         -1.508673                0.194371
# 37       0.243886         -0.225912                0.863181
# 17      -0.936818          0.962410                0.229023
# 64       0.638033         -0.675644               -0.896168
# 27      -1.074455          1.038459                0.717620
# 5        0.393740         -0.449952                0.362597
# 33      -0.550107          0.569409                1.073366
# 31      -0.625148          0.646606                1.131800
# 63       0.991367         -1.078468               -0.201772
# 35      -1.389738          1.343071               -1.133912
# 56       0.479911         -0.542449                0.142266
# 21       0.664758         -0.532610                0.967605
# 54      -0.993378          0.938207                0.362482
# 53      -0.047926          0.053759               -0.058553
# 49      -0.809791          0.822921                1.657512
# 8       -0.500733          0.452560               -0.653082
# 39      -2.600732          2.679125               -2.648674
# 42       0.719131         -0.668821                0.408653
# 15       0.693378         -0.739159                0.050185
# 43      -1.544508          1.716621                1.406424
# 13      -0.029702         -0.007221               -0.896213
# 66       1.946665         -1.840858               -0.348256
# 68       1.152910         -1.216108               -0.913665
# 14      -1.157532          1.098153               -0.225168
# 0        0.786074         -0.863957               -0.297797
# 28       0.090064         -0.098434                0.886206
# 58       1.504031         -1.591482                0.031615
# 6        1.201751         -1.085072                2.498778
# 23      -0.752604          0.737474                0.162778
# 45      -0.232040          0.213789                0.341049
# 25       1.280611         -1.101070                3.575984
# 26       0.247191         -0.297543               -0.639681
# 69       0.400674         -0.459388               -1.165688
# 7       -0.590585          0.669185               -0.313742
# 57       0.196208         -0.270156                0.493640
#
#     Difference Entropy (T3)  Difference Variance (T4)   E1 (K6)  \
# 11                -0.555099                 -0.695339  0.592338
# 70                 1.075001                  1.211064 -0.376303
# 44                 0.454262                  0.503337 -0.527604
# 36                -0.107842                 -0.166853 -0.226578
# 22                -2.151944                 -2.038913  0.364438
# 16                -1.540339                 -1.494517 -0.176750
# 12                 0.422172                  0.274985 -0.280404
# 55                -1.439514                 -1.342228 -0.157363
# 9                  1.529725                  1.920157  0.503623
# 51                -1.118130                 -1.378161  6.396529
# 38                 0.121628                  0.051333 -0.530088
# 41                -1.418319                 -1.506327  1.650484
# 3                  0.064837                 -0.500060 -1.074071
# 18                -1.062752                 -1.003241 -0.737498
# 59                 1.171224                  1.241845  0.162768
# 10                 0.577525                  0.329074  0.542053
# 67                 0.458856                  0.624470 -0.152170
# 73                 0.791243                  0.691652  0.578081
# 29                -0.258122                 -0.651329 -0.050707
# 48                 0.877783                  0.810734 -0.344051
# 61                 0.780333                  0.769835  1.306031
# 74                 1.093826                  1.312541 -0.457550
# 47                -1.119380                 -1.144992 -0.273894
# 20                 0.448471                 -0.110670  0.075446
# 60                -0.060503                  0.374589  0.242725
# 72                 1.371299                  1.148442 -0.219010
# 37                 0.330883                  0.279569 -0.280261
# 17                -0.866260                 -0.737657  0.448611
# 64                 0.567680                  0.809815  0.703473
# 27                -0.974652                 -1.052907 -0.594879
# 5                  0.377242                  0.521512  0.417698
# 33                -0.510949                 -0.309549 -0.384938
# 31                -0.410301                 -0.734366 -0.608103
# 63                 0.736785                  1.302193 -0.565426
# 35                -1.400614                 -1.333539 -0.261753
# 56                 0.525506                  0.425524  0.136699
# 21                 0.728276                  0.516568 -0.539504
# 54                -0.888405                 -0.940055 -0.277870
# 53                 0.110285                 -0.048719 -0.305590
# 49                -0.633818                 -0.865842 -0.833027
# 8                 -0.307044                 -0.637868 -0.382656
# 39                -3.496240                 -2.535233  1.849541
# 42                 0.827734                  0.377871 -0.823602
# 15                 0.663633                  0.765629 -0.010503
# 43                -1.845554                 -1.203773 -0.835255
# 13                 0.200856                 -0.313933 -0.749215
# 66                 1.614837                  1.620774 -0.246206
# 68                 0.995302                  1.258080 -0.193147
# 14                -1.012355                 -1.222999 -0.053476
# 0                  0.730739                  0.963743 -0.155749
# 28                 0.266811                  0.028521 -0.335433
# 58                 0.813457                  2.244654  0.237621
# 6                  1.083495                  1.144447 -1.095042
# 23                -0.604315                 -0.702216 -0.600079
# 45                 0.007398                 -0.395319 -0.726282
# 25                 1.159990                  1.199842 -0.962246
# 26                 0.246365                  0.421986 -0.163088
# 69                 0.365729                  0.569544 -0.906123
# 7                 -0.454189                 -0.496107 -0.583552
# 57                 0.304901                  0.193390 -0.205445
#
#     Effective Diameter (S2)  Energy (T5)  \
# 11                 0.478739    -0.177537
# 70                 0.086192     0.208081
# 44                -0.472722    -0.692318
# 36                 0.448158     0.283336
# 22                -0.814722     1.708167
# 16                 0.397194     1.037686
# 12                -0.760233    -1.100867
# 55                 0.710036     1.224460
# 9                  0.494166    -1.656450
# 51                 0.043263     1.122538
# 38                 0.264856     0.627115
# 41                -0.595781     0.637048
# 3                 -1.219394    -0.351964
# 18                -0.200882     0.637582
# 59                -1.047236    -0.751052
# 10                -0.184237    -0.884555
# 67                 0.136018    -0.333533
# 73                 0.359850    -1.299584
# 29                -0.958966    -0.073071
# 48                -1.055315    -0.550116
# 61                 0.110377     0.641576
# 74                -0.408864    -0.706740
# 47                 0.184589     0.759666
# 20                -0.724192    -0.599970
# 60                 0.338890     0.635768
# 72                -0.712017    -1.600481
# 37                 0.034572    -0.723164
# 17                 1.388652     2.152376
# 64                 1.129585    -0.825878
# 27                 0.839984     0.445330
# 5                  0.650652    -0.802541
# 33                 2.841064     0.428890
# 31                -0.956464     0.327324
# 63                -0.317585    -0.944201
# 35                 0.884240     1.078337
# 56                -0.306661    -0.945763
# 21                -1.331710    -0.379458
# 54                 0.635879     0.678650
# 53                -0.678590     0.566023
# 49                -0.845544     0.225441
# 8                 -0.387692    -0.418053
# 39                -0.634466     3.957082
# 42                -1.563874    -0.563382
# 15                 0.485753    -0.912988
# 43                -0.746933     2.387660
# 13                -0.620217    -0.684284
# 66                -0.911607    -1.830163
# 68                -0.251868    -0.248848
# 14                 0.255720     0.532559
# 0                 -0.125995     0.048001
# 28                 2.438326     0.011754
# 58                 1.009248    -0.821084
# 6                  0.154347    -0.833538
# 23                 0.224192     0.387257
# 45                -1.153223     0.185722
# 25                -0.636253    -0.520775
# 26                -0.350393    -0.620794
# 69                 0.598619    -0.672978
# 7                  4.839217     0.349525
# 57                -0.022480    -0.017724
#
#     Enhancement-Variance Time to Peak (E2)  \
# 11                               -1.065664
# 70                                1.473080
# 44                               -1.065664
# 36                                0.583773
# 22                               -1.065664
# 16                               -1.065664
# 12                                0.728260
# 55                               -1.065664
# 9                                 1.883668
# 51                               -0.487177
# 38                                1.062446
# 41                               -1.065664
# 3                                 0.746640
# 18                               -1.065664
# 59                                0.133908
# 10                               -1.065664
# 67                               -1.065664
# 73                                0.863055
# 29                                1.178056
# 48                                1.103692
# 61                                0.027945
# 74                               -1.065664
# 47                                0.660835
# 20                                0.327842
# 60                                1.040593
# 72                               -1.065664
# 37                                0.074663
# 17                                0.813076
# 64                               -1.065664
# 27                                1.531588
# 5                                 0.576232
# 33                               -1.065664
# 31                                0.402396
# 63                                1.089872
# 35                               -1.065664
# 56                               -1.065664
# 21                                1.030285
# 54                                1.006318
# 53                                0.118097
# 49                                0.859231
# 8                                -1.065664
# 39                                1.046476
# 42                                0.321586
# 15                                1.400495
# 43                               -0.624663
# 13                               -1.065664
# 66                                0.706983
# 68                               -1.065664
# 14                               -1.065664
# 0                                -1.065664
# 28                               -0.467360
# 58                                0.044737
# 6                                 2.582995
# 23                               -1.065664
# 45                               -1.065664
# 25                                0.960276
# 26                               -1.065664
# 69                                1.677010
# 7                                -0.210244
# 57                               -0.013855
#
#     Enhancement-variance Decreasing Rate (E4)  ...  \
# 11                                  -0.124209  ...
# 70                                  -0.126759  ...
# 44                                  -0.124914  ...
# 36                                  -0.124998  ...
# 22                                  -0.120363  ...
# 16                                  -0.126152  ...
# 12                                  -0.126759  ...
# 55                                  -0.122676  ...
# 9                                   -0.126759  ...
# 51                                   8.631473  ...
# 38                                  -0.126759  ...
# 41                                  -0.113247  ...
# 3                                   -0.126759  ...
# 18                                  -0.125343  ...
# 59                                  -0.111139  ...
# 10                                  -0.126756  ...
# 67                                  -0.125924  ...
# 73                                  -0.126759  ...
# 29                                  -0.126759  ...
# 48                                  -0.126759  ...
# 61                                   0.588806  ...
# 74                                  -0.126177  ...
# 47                                  -0.126759  ...
# 20                                  -0.087945  ...
# 60                                  -0.126759  ...
# 72                                  -0.126117  ...
# 37                                  -0.125649  ...
# 17                                  -0.126759  ...
# 64                                  -0.125891  ...
# 27                                  -0.126759  ...
# 5                                   -0.126759  ...
# 33                                  -0.126433  ...
# 31                                  -0.126392  ...
# 63                                  -0.126759  ...
# 35                                  -0.125588  ...
# 56                                  -0.123078  ...
# 21                                  -0.126759  ...
# 54                                  -0.126759  ...
# 53                                  -0.125468  ...
# 49                                  -0.126759  ...
# 8                                   -0.120277  ...
# 39                                  -0.126759  ...
# 42                                  -0.126759  ...
# 15                                  -0.126759  ...
# 43                                  -0.126229  ...
# 13                                  -0.126301  ...
# 66                                  -0.126759  ...
# 68                                  -0.125929  ...
# 14                                  -0.124163  ...
# 0                                   -0.125483  ...
# 28                                  -0.125476  ...
# 58                                  -0.126227  ...
# 6                                   -0.126759  ...
# 23                                  -0.126162  ...
# 45                                  -0.126422  ...
# 25                                  -0.126759  ...
# 26                                  -0.126177  ...
# 69                                  -0.126759  ...
# 7                                   -0.114425  ...
# 57                                  -0.124812  ...
#
#     ajcc_neoplasm_disease_stage_Stage IIB  \
# 11                                  False
# 70                                  False
# 44                                  False
# 36                                   True
# 22                                  False
# 16                                   True
# 12                                  False
# 55                                   True
# 9                                   False
# 51                                  False
# 38                                  False
# 41                                  False
# 3                                   False
# 18                                  False
# 59                                  False
# 10                                  False
# 67                                  False
# 73                                  False
# 29                                  False
# 48                                  False
# 61                                  False
# 74                                   True
# 47                                   True
# 20                                   True
# 60                                   True
# 72                                  False
# 37                                  False
# 17                                  False
# 64                                  False
# 27                                   True
# 5                                   False
# 33                                  False
# 31                                  False
# 63                                  False
# 35                                  False
# 56                                  False
# 21                                   True
# 54                                  False
# 53                                  False
# 49                                  False
# 8                                   False
# 39                                  False
# 42                                  False
# 15                                   True
# 43                                  False
# 13                                  False
# 66                                  False
# 68                                  False
# 14                                  False
# 0                                   False
# 28                                   True
# 58                                  False
# 6                                    True
# 23                                  False
# 45                                  False
# 25                                  False
# 26                                  False
# 69                                  False
# 7                                   False
# 57                                  False
#
#     ajcc_neoplasm_disease_stage_Stage IIIA  \
# 11                                   False
# 70                                   False
# 44                                   False
# 36                                   False
# 22                                   False
# 16                                   False
# 12                                   False
# 55                                   False
# 9                                    False
# 51                                   False
# 38                                   False
# 41                                   False
# 3                                    False
# 18                                   False
# 59                                   False
# 10                                   False
# 67                                   False
# 73                                   False
# 29                                   False
# 48                                   False
# 61                                   False
# 74                                   False
# 47                                   False
# 20                                   False
# 60                                   False
# 72                                   False
# 37                                   False
# 17                                    True
# 64                                   False
# 27                                   False
# 5                                    False
# 33                                   False
# 31                                   False
# 63                                   False
# 35                                    True
# 56                                   False
# 21                                   False
# 54                                   False
# 53                                   False
# 49                                   False
# 8                                    False
# 39                                   False
# 42                                   False
# 15                                   False
# 43                                    True
# 13                                   False
# 66                                   False
# 68                                   False
# 14                                    True
# 0                                    False
# 28                                   False
# 58                                   False
# 6                                    False
# 23                                   False
# 45                                   False
# 25                                   False
# 26                                   False
# 69                                   False
# 7                                    False
# 57                                   False
#
#     ajcc_neoplasm_disease_stage_Stage IIIC  ajcc_tumor_stage_code_T1b  \
# 11                                   False                      False
# 70                                   False                      False
# 44                                   False                      False
# 36                                   False                      False
# 22                                   False                      False
# 16                                   False                      False
# 12                                   False                      False
# 55                                   False                      False
# 9                                    False                      False
# 51                                   False                      False
# 38                                   False                      False
# 41                                   False                      False
# 3                                    False                      False
# 18                                   False                      False
# 59                                   False                      False
# 10                                   False                      False
# 67                                   False                      False
# 73                                   False                      False
# 29                                   False                      False
# 48                                   False                      False
# 61                                   False                      False
# 74                                   False                      False
# 47                                   False                      False
# 20                                   False                      False
# 60                                   False                      False
# 72                                   False                      False
# 37                                   False                      False
# 17                                   False                      False
# 64                                    True                      False
# 27                                   False                      False
# 5                                    False                      False
# 33                                    True                      False
# 31                                   False                       True
# 63                                   False                      False
# 35                                   False                      False
# 56                                   False                      False
# 21                                   False                      False
# 54                                   False                      False
# 53                                   False                      False
# 49                                   False                      False
# 8                                    False                      False
# 39                                   False                      False
# 42                                   False                       True
# 15                                   False                      False
# 43                                   False                      False
# 13                                   False                      False
# 66                                   False                      False
# 68                                   False                      False
# 14                                   False                      False
# 0                                    False                      False
# 28                                   False                      False
# 58                                    True                      False
# 6                                    False                      False
# 23                                   False                      False
# 45                                   False                      False
# 25                                   False                      False
# 26                                   False                      False
# 69                                   False                      False
# 7                                    False                      False
# 57                                   False                      False
#
#     ajcc_tumor_stage_code_T1c  ajcc_tumor_stage_code_T2  \
# 11                      False                     False
# 70                      False                      True
# 44                      False                      True
# 36                      False                      True
# 22                       True                     False
# 16                      False                      True
# 12                      False                      True
# 55                      False                      True
# 9                       False                      True
# 51                      False                      True
# 38                      False                      True
# 41                       True                     False
# 3                        True                     False
# 18                       True                     False
# 59                       True                     False
# 10                      False                     False
# 67                      False                      True
# 73                      False                      True
# 29                       True                     False
# 48                       True                     False
# 61                      False                      True
# 74                      False                      True
# 47                      False                      True
# 20                      False                      True
# 60                      False                      True
# 72                      False                      True
# 37                       True                     False
# 17                      False                      True
# 64                      False                      True
# 27                      False                      True
# 5                        True                     False
# 33                      False                     False
# 31                      False                     False
# 63                      False                      True
# 35                      False                      True
# 56                      False                      True
# 21                      False                      True
# 54                      False                      True
# 53                       True                     False
# 49                       True                     False
# 8                       False                      True
# 39                       True                     False
# 42                      False                     False
# 15                      False                      True
# 43                       True                     False
# 13                       True                     False
# 66                       True                     False
# 68                       True                     False
# 14                      False                     False
# 0                        True                     False
# 28                      False                      True
# 58                      False                      True
# 6                       False                     False
# 23                       True                     False
# 45                       True                     False
# 25                      False                      True
# 26                      False                      True
# 69                      False                      True
# 7                       False                      True
# 57                      False                      True
#
#     ajcc_tumor_stage_code_T3  \
# 11                     False
# 70                     False
# 44                     False
# 36                     False
# 22                     False
# 16                     False
# 12                     False
# 55                     False
# 9                      False
# 51                     False
# 38                     False
# 41                     False
# 3                      False
# 18                     False
# 59                     False
# 10                     False
# 67                     False
# 73                     False
# 29                     False
# 48                     False
# 61                     False
# 74                     False
# 47                     False
# 20                     False
# 60                     False
# 72                     False
# 37                     False
# 17                     False
# 64                     False
# 27                     False
# 5                      False
# 33                      True
# 31                     False
# 63                     False
# 35                     False
# 56                     False
# 21                     False
# 54                     False
# 53                     False
# 49                     False
# 8                      False
# 39                     False
# 42                     False
# 15                     False
# 43                     False
# 13                     False
# 66                     False
# 68                     False
# 14                      True
# 0                      False
# 28                     False
# 58                     False
# 6                       True
# 23                     False
# 45                     False
# 25                     False
# 26                     False
# 69                     False
# 7                      False
# 57                     False
#
#     breast_carcinoma_estrogen_receptor_status_Positive  \
# 11                                               True
# 70                                               True
# 44                                               True
# 36                                               True
# 22                                               True
# 16                                              False
# 12                                               True
# 55                                               True
# 9                                               False
# 51                                               True
# 38                                               True
# 41                                               True
# 3                                                True
# 18                                               True
# 59                                               True
# 10                                               True
# 67                                               True
# 73                                              False
# 29                                               True
# 48                                               True
# 61                                               True
# 74                                               True
# 47                                               True
# 20                                               True
# 60                                               True
# 72                                               True
# 37                                               True
# 17                                               True
# 64                                               True
# 27                                               True
# 5                                               False
# 33                                              False
# 31                                               True
# 63                                              False
# 35                                               True
# 56                                               True
# 21                                               True
# 54                                               True
# 53                                               True
# 49                                               True
# 8                                                True
# 39                                               True
# 42                                               True
# 15                                               True
# 43                                               True
# 13                                               True
# 66                                               True
# 68                                               True
# 14                                               True
# 0                                                True
# 28                                               True
# 58                                              False
# 6                                                True
# 23                                               True
# 45                                               True
# 25                                               True
# 26                                               True
# 69                                               True
# 7                                               False
# 57                                               True
#
#     breast_carcinoma_progesterone_receptor_status_Positive  \
# 11                                               True
# 70                                               True
# 44                                               True
# 36                                               True
# 22                                               True
# 16                                              False
# 12                                               True
# 55                                               True
# 9                                               False
# 51                                               True
# 38                                               True
# 41                                               True
# 3                                               False
# 18                                               True
# 59                                               True
# 10                                               True
# 67                                               True
# 73                                              False
# 29                                               True
# 48                                              False
# 61                                               True
# 74                                               True
# 47                                               True
# 20                                               True
# 60                                               True
# 72                                               True
# 37                                               True
# 17                                               True
# 64                                               True
# 27                                               True
# 5                                               False
# 33                                              False
# 31                                               True
# 63                                              False
# 35                                               True
# 56                                              False
# 21                                              False
# 54                                               True
# 53                                               True
# 49                                               True
# 8                                                True
# 39                                               True
# 42                                               True
# 15                                               True
# 43                                               True
# 13                                              False
# 66                                               True
# 68                                               True
# 14                                               True
# 0                                                True
# 28                                               True
# 58                                              False
# 6                                                True
# 23                                               True
# 45                                               True
# 25                                               True
# 26                                              False
# 69                                               True
# 7                                               False
# 57                                               True
#
#     number_of_lymphnodes_positive_by_he
# 11                                  0.0
# 70                                  0.0
# 44                                  0.0
# 36                                  3.0
# 22                                  0.0
# 16                                  2.0
# 12                                  0.0
# 55                                  2.0
# 9                                   0.0
# 51                                  0.0
# 38                                  3.0
# 41                                  0.0
# 3                                   0.0
# 18                                  0.0
# 59                                  0.0
# 10                                  0.0
# 67                                  0.0
# 73                                  0.0
# 29                                  1.0
# 48                                  0.0
# 61                                  0.0
# 74                                  1.0
# 47                                  2.0
# 20                                  2.0
# 60                                  3.0
# 72                                  0.0
# 37                                  4.0
# 17                                  5.0
# 64                                 13.0
# 27                                  3.0
# 5                                   1.0
# 33                                 10.0
# 31                                  0.0
# 63                                  0.0
# 35                                  4.0
# 56                                  0.0
# 21                                  3.0
# 54                                  0.0
# 53                                  1.0
# 49                                  1.0
# 8                                   0.0
# 39                                  1.0
# 42                                  0.0
# 15                                  1.0
# 43                                  6.0
# 13                                  2.0
# 66                                  1.0
# 68                                  0.0
# 14                                  1.0
# 0                                   0.0
# 28                                  3.0
# 58                                 10.0
# 6                                   0.0
# 23                                  NaN
# 45                                  0.0
# 25                                  0.0
# 26                                  0.0
# 69                                  2.0
# 7                                   0.0
# 57                                  0.0
#
# [60 rows x 50 columns]

# %%
under_sampler = RandomUnderSampler(sampling_strategy={"LumA": 30}, random_state=42)
X_train_under, y_train_under = under_sampler.fit_resample(X_train, y_train)

over_sampler = SMOTE(sampling_strategy="not majority", random_state=42, k_neighbors=3)
X_train_resampled, y_train_resampled = over_sampler.fit_resample(X_train_under, y_train_under)

print("\nDistribución tras Under-Sampling + Over-Sampling en train:")
print(y_train_resampled.value_counts())
# Out:
# Distribución tras Under-Sampling + Over-Sampling en train:
# Pam50.Call
# Basal    30
# Her2     30
# LumA     30
# LumB     30
# Name: count, dtype: int64

# %%
df_resampled = pd.concat(
    [pd.DataFrame(X_train_resampled), pd.Series(y_train_resampled, name='Pam50.Call')],
    axis=1
)

# %%
df_train = df_resampled

# %%
selected_features = ['Margin Sharpness (M1)', 'Maximum enhancement-variance (E1)', 'Surface Area (S3)'] + list(new_dummy_columns)

# %%
X_train_resampled_selected = X_train_resampled[selected_features]
X_test_selected = X_test[selected_features]

# %%
def train_and_evaluate_model(X_train, X_test, y_train, y_test, features, target_col, model, imprimir=False):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    macro_f1 = f1_score(y_test, y_pred, average='macro')
    if imprimir:
        print("Classification Report:")
        print(classification_report(y_test, y_pred))
    return macro_f1

# %%
rf_model = RandomForestClassifier(random_state=42)

macro_f1_score = train_and_evaluate_model(
    X_train_resampled_selected, X_test_selected, y_train_resampled, y_test,
    features=[col for col in df.columns if col != "Pam50.Call"],
    target_col="Pam50.Call",
    model=rf_model,
    imprimir=True
)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        Basal       1.00      1.00      1.00         2
#         Her2       1.00      1.00      1.00         1
#         LumA       0.89      0.73      0.80        11
#         LumB       0.25      0.50      0.33         2
#
#     accuracy                           0.75        16
#    macro avg       0.78      0.81      0.78        16
# weighted avg       0.83      0.75      0.78        16
